# %% [markdown]
# ## Projeto Data Brazil

# %%
import pandas as pd
import csv
import json

# %%
data_22 = pd.read_csv('data/Data_2022.csv')

# %%
data_22
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96                39.0
# 1     zzls2oftfn9law393oezzls2ofhvfpzd                32.0
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi                53.0
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl                27.0
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg                46.0
# ...                                ...                 ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp                26.0
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp                30.0
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3                29.0
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de                 NaN
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7                24.0
#
#      ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         35-39           Masculino
# 1                         30-34           Masculino
# 2                         50-54           Masculino
# ...

# %%
data_22.columns = data_22.columns.str.split(',').str[1].str.replace("[)']",'' ,regex=True).str.strip()

# %%
data_22
# Out:
#                                     id  Idade Faixa idade     Genero  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# ...                                ...    ...         ...        ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      Cor/raca/etnia  PCD               experiencia_profissional_prejudicada  \
# ...

# %%
data_22.to_csv('databrazil.csv')

# %%
etnias = [{'Branco': 43, 'Pardo': 47, 'Preto': 9.1},
    {'Branco': 17.7, 'Pardo': 73.4, 'Preto': 7.5},
    {'Branco': 24.7, 'Pardo': 63.1, 'Preto':11.4},
    {'Branco': 50.7, 'Pardo': 38.7, 'Preto': 9.6},
    {'Branco': 75.1, 'Pardo': 19.9, 'Preto': 4.4},
    {'Branco': 34.7, 'Pardo': 55.8, 'Preto': 8.7}
]

df = pd.DataFrame(etnias)

# %%
etnia_brasil21 = df.rename(index={0: 'Brasil', 1: 'Norte', 2: 'Nordeste', 3: 'Sudeste', 4: 'Sul', 5: 'Centro-Oeste'})

# %%
etnia_brasil21
# Out:
#               Branco  Pardo  Preto
# Brasil          43.0   47.0    9.1
# Norte           17.7   73.4    7.5
# Nordeste        24.7   63.1   11.4
# Sudeste         50.7   38.7    9.6
# Sul             75.1   19.9    4.4
# Centro-Oeste    34.7   55.8    8.7

# %%
etnia_brasil21.to_csv('etnia_brasil21.csv')
